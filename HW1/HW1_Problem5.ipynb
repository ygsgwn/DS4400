# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df_cleaned = df.drop(columns=['price','id','date','zipcode'])

# %%
#5.1
stats = pd.DataFrame({
    'Average': df_cleaned.mean(),
    'Min': df_cleaned.min(),
    'Max': df_cleaned.max(),
    'Variance': df_cleaned.var()
})
print('Lowest Average: ', stats['Average'].idxmin(), stats['Average'].min())
print('Highest Average: ', stats['Average'].idxmax(), stats['Average'].max())
print('Lowest Variance: ', stats['Variance'].idxmin(), stats['Variance'].min())
print('Highest Variance: ', stats['Variance'].idxmax(), stats['Variance'].max())
df_cleaened.stats()
# Out:
# Lowest Average:  long -122.21389640494147
# Highest Average:  sqft_lot 15106.967565816869
# Lowest Variance:  waterfront 0.007485225502686407
# Highest Variance:  sqft_lot 1715658774.1754704
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 12
#      10 print('Lowest Variance: ', stats['Variance'].idxmin(), stats['Variance'].min())
#      11 print('Highest Variance: ', stats['Variance'].idxmax(), stats['Variance'].max())
# ---> 12 df_cleaened.stats()
#
# NameError: name 'df_cleaened' is not defined

# %%
#5.2
y = df['price']
corr = df_cleaned.corrwith(y)
corr_table = corr.sort_values(ascending=False).to_frame(
    name="correlation_with_price"
)
print(corr_table)
print()
positive_features = corr_table[corr_table["correlation_with_price"] > 0]
print(positive_features.index.tolist())
print('All features are positively correlated with the response')
print('Highest Positive Correlation: ', corr_table['correlation_with_price'].idxmax())
# Out:
#                correlation_with_price
# sqft_living                  0.702035
# grade                        0.667434
# sqft_above                   0.605567
# sqft_living15                0.585379
# bathrooms                    0.525138
# view                         0.397293
# sqft_basement                0.323816
# bedrooms                     0.308350
# lat                          0.307003
# waterfront                   0.266369
# floors                       0.256794
# yr_renovated                 0.126434
# sqft_lot                     0.089661
# sqft_lot15                   0.082447
# yr_built                     0.054012
# condition                    0.036362
# long                         0.021626
#
# ['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms', 'lat', 'waterfront', 'floors', 'yr_renovated', 'sqft_lot', 'sqft_lot15', 'yr_built', 'condition', 'long']
# All features are positively correlated with the response
# Highest Positive Correlation:  sqft_living

# %%
#5.3
negative_features = corr_table[corr_table["correlation_with_price"] < 0]

if negative_features.empty:
    print("No features have negative correlation with price.")
else:
    negative_features
# Out:
# No features have negative correlation with price.
